# %%
import pandas as pd
import seaborn as sns

# %%
salary = pd.read_csv("Salary_dataset.csv")

# %%
df = pd.DataFrame(salary)

# %%
sns.set_theme(style="darkgrid")
sns.jointplot(data=df, x=df['YearsExperience'], y=df['Salary'], color="m")
